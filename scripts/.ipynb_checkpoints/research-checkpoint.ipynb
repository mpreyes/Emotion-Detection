# %%
import sys
import os
import numpy as np
from PIL import Image
import glob
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Reshape, Dropout
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from keras.callbacks import ModelCheckpoint
from keras.preprocessing import image as keras_image
from keras.utils.np_utils import to_categorical
from keras.applications.resnet50 import ResNet50
from keras.applications.vgg19 import VGG19
from keras.models import Model
from keras.models import model_from_json

# %%
# Main program
IMAGES_PATH = "../inputs/images/"
LABELS_PATH = "../inputs/labels/"

# %%
#def read_inputs():
X = []
Y = []
for root, dirs, files, in os.walk(LABELS_PATH):
    for file in files:
        #print (d)
        if file.endswith(".txt") and not file.startswith("."): #grabbing the inner dirs, should be 593
            images_path = root.replace(LABELS_PATH, IMAGES_PATH)
            images      = list(filter(lambda x: not x.startswith("."), os.listdir(images_path))) # keep images that doesn't start with .
            
            label_file = open(os.path.join(root,file),"r")
            label = int(float(label_file.readline().strip("\n")))
            
            print (images_path + ' ==> ' + str(label))
            
            images.sort() # only get the last four (maybe?)
            for img in images[-4:]:
                tmp = keras_image.load_img(images_path + "/" + img , target_size=(224, 224))
                tmp = keras_image.img_to_array(tmp) / float(255)
                X.append(tmp)
                Y.append(label)
# Out:
# ../inputs/images/S111/007 ==> 3
# ../inputs/images/S111/001 ==> 7
# ../inputs/images/S111/006 ==> 1
# ../inputs/images/S129/012 ==> 5
# ../inputs/images/S129/006 ==> 1
# ../inputs/images/S129/011 ==> 3
# ../inputs/images/S129/002 ==> 7
# ../inputs/images/S116/007 ==> 5
# ../inputs/images/S116/001 ==> 7
# ../inputs/images/S116/006 ==> 3
# ../inputs/images/S127/001 ==> 7
# ../inputs/images/S127/010 ==> 1
# ../inputs/images/S127/004 ==> 5
# ../inputs/images/S119/008 ==> 1
# ../inputs/images/S119/001 ==> 7
# ../inputs/images/S119/003 ==> 4
# ../inputs/images/S126/008 ==> 1
# ../inputs/images/S126/004 ==> 7
# ../inputs/images/S128/011 ==> 5
# ../inputs/images/S128/004 ==> 3
# ../inputs/images/S117/001 ==> 7
# ../inputs/images/S117/006 ==> 1
# ../inputs/images/S117/003 ==> 4
# ../inputs/images/S110/001 ==> 7
# ../inputs/images/S096/001 ==> 7
# ../inputs/images/S096/003 ==> 3
# ../inputs/images/S096/004 ==> 5
# ../inputs/images/S062/001 ==> 4
# ../inputs/images/S062/004 ==> 5
# ../inputs/images/S062/005 ==> 3
# ../inputs/images/S062/002 ==> 7
# ../inputs/images/S895/002 ==> 2
# ../inputs/images/S065/003 ==> 7
# ../inputs/images/S065/004 ==> 5
# ../inputs/images/S065/005 ==> 3
# ../inputs/images/S065/002 ==> 4
# ../inputs/images/S091/001 ==> 4
# ../inputs/images/S091/003 ==> 5
# ../inputs/images/S053/001 ==> 7
# ../inputs/images/S053/004 ==> 5
# ../inputs/images/S098/003 ==> 3
# ../inputs/images/S098/004 ==> 5
# ../inputs/images/S054/003 ==> 7
# ../inputs/images/S054/004 ==> 3
# ../inputs/images/S054/002 ==> 4
# ../inputs/images/S037/001 ==> 7
# ../inputs/images/S037/006 ==> 5
# ../inputs/images/S037/003 ==> 1
# ../inputs/images/S055/001 ==> 7
# ../inputs/images/S055/006 ==> 4
# ../inputs/images/S055/003 ==> 3
# ../inputs/images/S055/004 ==> 1
# ../inputs/images/S055/005 ==> 5
# ../inputs/images/S052/001 ==> 7
# ../inputs/images/S052/006 ==> 3
# ../inputs/images/S052/004 ==> 5
# ../inputs/images/S099/007 ==> 3
# ../inputs/images/S099/001 ==> 7
# ../inputs/images/S099/004 ==> 5
# ../inputs/images/S090/007 ==> 1
# ../inputs/images/S090/006 ==> 3
# ../inputs/images/S090/002 ==> 7
# ../inputs/images/S064/001 ==> 7
# ../inputs/images/S064/003 ==> 5
# ../inputs/images/S064/004 ==> 6
# ../inputs/images/S063/001 ==> 7
# ../inputs/images/S063/002 ==> 5
# ../inputs/images/S097/001 ==> 7
# ../inputs/images/S097/006 ==> 5
# ../inputs/images/S097/004 ==> 3
# ../inputs/images/S079/001 ==> 7
# ../inputs/images/S079/004 ==> 5
# ../inputs/images/S079/002 ==> 3
# ../inputs/images/S046/001 ==> 6
# ../inputs/images/S046/003 ==> 4
# ../inputs/images/S046/004 ==> 3
# ../inputs/images/S046/002 ==> 7
# ../inputs/images/S084/001 ==> 7
# ../inputs/images/S084/002 ==> 4
# ../inputs/images/S070/003 ==> 5
# ../inputs/images/S070/005 ==> 3
# ../inputs/images/S070/002 ==> 7
# ../inputs/images/S077/001 ==> 7
# ../inputs/images/S077/006 ==> 3
# ../inputs/images/S083/003 ==> 5
# ../inputs/images/S082/007 ==> 3
# ../inputs/images/S082/001 ==> 7
# ../inputs/images/S082/005 ==> 1
# ../inputs/images/S076/001 ==> 7
# ../inputs/images/S076/006 ==> 5
# ../inputs/images/S076/005 ==> 3
# ../inputs/images/S071/001 ==> 7
# ../inputs/images/S071/006 ==> 3
# ../inputs/images/S071/004 ==> 1
# ../inputs/images/S071/005 ==> 5
# ../inputs/images/S071/002 ==> 6
# ../inputs/images/S085/003 ==> 7
# ../inputs/images/S085/004 ==> 3
# ../inputs/images/S085/002 ==> 5
# ../inputs/images/S078/007 ==> 3
# ../inputs/images/S078/001 ==> 7
# ../inputs/images/S078/004 ==> 5
# ../inputs/images/S014/001 ==> 7
# ../inputs/images/S014/003 ==> 1
# ../inputs/images/S014/005 ==> 5
# ../inputs/images/S014/002 ==> 6
# ../inputs/images/S022/001 ==> 7
# ../inputs/images/S022/006 ==> 3
# ../inputs/images/S022/005 ==> 1
# ../inputs/images/S157/002 ==> 2
# ../inputs/images/S505/006 ==> 6
# ../inputs/images/S505/002 ==> 2
# ../inputs/images/S502/001 ==> 1
# ../inputs/images/S502/004 ==> 4
# ../inputs/images/S502/002 ==> 2
# ../inputs/images/S132/008 ==> 7
# ../inputs/images/S132/006 ==> 5
# ../inputs/images/S132/003 ==> 4
# ../inputs/images/S132/005 ==> 3
# ../inputs/images/S132/002 ==> 6
# ../inputs/images/S135/012 ==> 5
# ../inputs/images/S135/001 ==> 7
# ../inputs/images/S158/002 ==> 2
# ../inputs/images/S503/001 ==> 1
# ../inputs/images/S503/006 ==> 6
# ../inputs/images/S503/002 ==> 2
# ../inputs/images/S504/001 ==> 1
# ../inputs/images/S504/006 ==> 6
# ../inputs/images/S504/004 ==> 4
# ../inputs/images/S504/002 ==> 2
# ../inputs/images/S160/006 ==> 2
# ../inputs/images/S156/002 ==> 2
# ../inputs/images/S999/001 ==> 1
# ../inputs/images/S999/003 ==> 4
# ../inputs/images/S151/002 ==> 2
# ../inputs/images/S105/008 ==> 3
# ../inputs/images/S102/009 ==> 3
# ../inputs/images/S102/003 ==> 4
# ../inputs/images/S102/002 ==> 7
# ../inputs/images/S134/008 ==> 3
# ../inputs/images/S134/003 ==> 1
# ../inputs/images/S134/004 ==> 5
# ../inputs/images/S133/009 ==> 7
# ../inputs/images/S133/010 ==> 5
# ../inputs/images/S133/003 ==> 1
# ../inputs/images/S148/002 ==> 2
# ../inputs/images/S115/008 ==> 5
# ../inputs/images/S115/001 ==> 7
# ../inputs/images/S115/004 ==> 6
# ../inputs/images/S112/005 ==> 1
# ../inputs/images/S124/007 ==> 5
# ../inputs/images/S124/001 ==> 7
# ../inputs/images/S124/006 ==> 3
# ../inputs/images/S124/003 ==> 4
# ../inputs/images/S147/002 ==> 2
# ../inputs/images/S149/002 ==> 2
# ../inputs/images/S122/001 ==> 7
# ../inputs/images/S125/007 ==> 7
# ../inputs/images/S125/008 ==> 3
# ../inputs/images/S125/001 ==> 6
# ../inputs/images/S125/006 ==> 4
# ../inputs/images/S125/005 ==> 5
# ../inputs/images/S113/008 ==> 1
# ../inputs/images/S113/001 ==> 7
# ../inputs/images/S113/003 ==> 6
# ../inputs/images/S114/001 ==> 7
# ../inputs/images/S114/006 ==> 5
# ../inputs/images/S066/003 ==> 5
# ../inputs/images/S066/004 ==> 6
# ../inputs/images/S066/005 ==> 1
# ../inputs/images/S066/002 ==> 7
# ../inputs/images/S092/001 ==> 7
# ../inputs/images/S092/003 ==> 1
# ../inputs/images/S092/004 ==> 5
# ../inputs/images/S059/001 ==> 7
# ../inputs/images/S059/002 ==> 4
# ../inputs/images/S095/007 ==> 5
# ../inputs/images/S095/001 ==> 7
# ../inputs/images/S095/006 ==> 3
# ../inputs/images/S095/010 ==> 6
# ../inputs/images/S061/001 ==> 7
# ../inputs/images/S061/004 ==> 3
# ../inputs/images/S061/002 ==> 5
# ../inputs/images/S057/001 ==> 7
# ../inputs/images/S057/006 ==> 5
# ../inputs/images/S057/003 ==> 3
# ../inputs/images/S068/003 ==> 7
# ../inputs/images/S068/004 ==> 4
# ../inputs/images/S068/005 ==> 3
# ../inputs/images/S068/002 ==> 5
# ../inputs/images/S050/001 ==> 4
# ../inputs/images/S050/006 ==> 5
# ../inputs/images/S050/004 ==> 1
# ../inputs/images/S050/002 ==> 7
# ../inputs/images/S035/001 ==> 7
# ../inputs/images/S035/006 ==> 5
# ../inputs/images/S035/005 ==> 3
# ../inputs/images/S032/001 ==> 7
# ../inputs/images/S032/006 ==> 5
# ../inputs/images/S032/003 ==> 1
# ../inputs/images/S032/004 ==> 4
# ../inputs/images/S032/005 ==> 3
# ../inputs/images/S051/003 ==> 3
# ../inputs/images/S051/002 ==> 7
# ../inputs/images/S056/003 ==> 7
# ../inputs/images/S056/004 ==> 5
# ../inputs/images/S056/002 ==> 3
# ../inputs/images/S069/003 ==> 3
# ../inputs/images/S069/004 ==> 5
# ../inputs/images/S069/002 ==> 7
# ../inputs/images/S060/003 ==> 7
# ../inputs/images/S060/005 ==> 3
# ../inputs/images/S060/002 ==> 5
# ../inputs/images/S094/001 ==> 7
# ../inputs/images/S094/004 ==> 5
# ../inputs/images/S093/001 ==> 6
# ../inputs/images/S093/004 ==> 5
# ../inputs/images/S067/006 ==> 3
# ../inputs/images/S067/004 ==> 1
# ../inputs/images/S067/005 ==> 5
# ../inputs/images/S067/002 ==> 7
# ../inputs/images/S058/001 ==> 7
# ../inputs/images/S058/006 ==> 3
# ../inputs/images/S058/005 ==> 1
# ../inputs/images/S034/001 ==> 7
# ../inputs/images/S034/003 ==> 1
# ../inputs/images/S034/005 ==> 5
# ../inputs/images/S005/001 ==> 3
# ../inputs/images/S029/001 ==> 1
# ../inputs/images/S011/001 ==> 7
# ../inputs/images/S011/006 ==> 5
# ../inputs/images/S011/003 ==> 4
# ../inputs/images/S011/004 ==> 1
# ../inputs/images/S011/005 ==> 3
# ../inputs/images/S011/002 ==> 6
# ../inputs/images/S045/004 ==> 3
# ../inputs/images/S045/005 ==> 1
# ../inputs/images/S089/001 ==> 7
# ../inputs/images/S089/003 ==> 1
# ../inputs/images/S089/002 ==> 5
# ../inputs/images/S042/001 ==> 7
# ../inputs/images/S042/006 ==> 5
# ../inputs/images/S042/004 ==> 1
# ../inputs/images/S042/002 ==> 6
# ../inputs/images/S074/001 ==> 4
# ../inputs/images/S074/004 ==> 3
# ../inputs/images/S074/005 ==> 5
# ../inputs/images/S074/002 ==> 7
# ../inputs/images/S080/008 ==> 3
# ../inputs/images/S080/001 ==> 7
# ../inputs/images/S080/005 ==> 6
# ../inputs/images/S087/007 ==> 1
# ../inputs/images/S087/001 ==> 7
# ../inputs/images/S087/004 ==> 3
# ../inputs/images/S087/005 ==> 5
# ../inputs/images/S073/001 ==> 7
# ../inputs/images/S073/006 ==> 3
# ../inputs/images/S010/006 ==> 5
# ../inputs/images/S010/004 ==> 1
# ../inputs/images/S010/002 ==> 7
# ../inputs/images/S028/001 ==> 1
# ../inputs/images/S026/001 ==> 7
# ../inputs/images/S026/006 ==> 5
# ../inputs/images/S026/003 ==> 1
# ../inputs/images/S026/002 ==> 6
# ../inputs/images/S072/006 ==> 5
# ../inputs/images/S072/005 ==> 1
# ../inputs/images/S086/001 ==> 7
# ../inputs/images/S086/002 ==> 5
# ../inputs/images/S081/008 ==> 3
# ../inputs/images/S081/001 ==> 7
# ../inputs/images/S081/002 ==> 6
# ../inputs/images/S075/008 ==> 1
# ../inputs/images/S075/006 ==> 5
# ../inputs/images/S075/005 ==> 3
# ../inputs/images/S075/002 ==> 7
# ../inputs/images/S088/001 ==> 7
# ../inputs/images/S088/004 ==> 3
# ../inputs/images/S044/001 ==> 7
# ../inputs/images/S044/006 ==> 3
# ../inputs/images/S044/003 ==> 5
# ../inputs/images/S136/001 ==> 7
# ../inputs/images/S136/006 ==> 5
# ../inputs/images/S136/003 ==> 6
# ../inputs/images/S136/005 ==> 1
# ../inputs/images/S109/006 ==> 5
# ../inputs/images/S109/003 ==> 1
# ../inputs/images/S109/005 ==> 3
# ../inputs/images/S131/001 ==> 7
# ../inputs/images/S131/006 ==> 5
# ../inputs/images/S131/010 ==> 3
# ../inputs/images/S131/003 ==> 6
# ../inputs/images/S107/001 ==> 7
# ../inputs/images/S107/005 ==> 3
# ../inputs/images/S138/007 ==> 6
# ../inputs/images/S138/008 ==> 2
# ../inputs/images/S138/001 ==> 4
# ../inputs/images/S138/004 ==> 7
# ../inputs/images/S138/005 ==> 5
# ../inputs/images/S100/006 ==> 5
# ../inputs/images/S100/005 ==> 1
# ../inputs/images/S100/002 ==> 7
# ../inputs/images/S154/002 ==> 2
# ../inputs/images/S501/001 ==> 1
# ../inputs/images/S501/006 ==> 6
# ../inputs/images/S501/004 ==> 4
# ../inputs/images/S506/001 ==> 1
# ../inputs/images/S506/006 ==> 6
# ../inputs/images/S506/004 ==> 4
# ../inputs/images/S506/002 ==> 2
# ../inputs/images/S101/002 ==> 7
# ../inputs/images/S106/006 ==> 5
# ../inputs/images/S106/004 ==> 3
# ../inputs/images/S106/002 ==> 6
# ../inputs/images/S139/002 ==> 2
# ../inputs/images/S130/012 ==> 3
# ../inputs/images/S130/013 ==> 5
# ../inputs/images/S130/007 ==> 1
# ../inputs/images/S130/009 ==> 6
# ../inputs/images/S130/001 ==> 7
# ../inputs/images/S137/001 ==> 7
# ../inputs/images/S137/011 ==> 5
# ../inputs/images/S137/005 ==> 6
# ../inputs/images/S108/008 ==> 5
# ../inputs/images/S108/006 ==> 3
# ../inputs/images/S108/005 ==> 6
# ../inputs/images/S155/002 ==> 2

# %%
def getLabels(rootdir,extension): #grabbing labels from labels folder
    labels = []
    for root, dirs, files, in sorted(os.walk(rootdir)):
        for f in files:
            #print("files " + str(f))
            if f.endswith(extension) and not f.startswith("."):
                #print("label " + str(f),end=" ")
                f = open(os.path.join(root,f),"r")
                l = int(float(f.readline().strip("\n")))
                labels.append(l)
                #print(str(l))
    return labels

# %%
def resizeImages(img_files,x,y):
    for i in range(len(img_files)): 
        img = image.load_img(img_files[i][1], target_size=(224, 224))
        resized_img = image.img_to_array(img) #numpy array
        resized_img = resized_img / float(255)
        x.append(resized_img)
        y.append(img_files[i][0])
        #print("res im " + str(resized_img) + " " + str(img_files[i][0]))
    return np.asarray(x), np.asarray(y)

# %%
def simple_model():
    model = Sequential()
    model.add(Flatten(input_shape=(64, 64, 3)))
    model.add(Dense(units=64, activation='relu'))
    model.add(Dense(units=7, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])
    
    return model

# %%
def VGGNET16():
    vgg16 = VGG16(weights='imagenet', include_top=False, input_shape = (64,64,3)) 
    
    stacked = Flatten()(vgg16.output)
    stacked = Dense(8, activation='relu')(stacked)
    predictions = Dense(1, activation='relu')(stacked)
    model = Model(input=vgg16.input, output=predictions)
    model.compile(loss='mean_squared_error', optimizer='rmsprop')
    
    return model

# %%
model = simple_model()
model.fit(X, Y, epochs=5, batch_size=32)
